# %%
import {useState, useRef, useEffect} from "react"  
##  usestate stores data that changes like input messages
## useRef points to a specific element on the page and useeffect runs code automatically when something changes.

const bottomRef = useRef(null);
## this creates a pointer on the page that makes us scroll automatically
useEffect(() => {
    bottomRef.current?.scrollIntoView({ behavior: "smooth" });
  }, [messages, loading]);
## simply means when a new messages arrives scroll to the bottom.

const sendMessage = async () => {
  # this function runs when the user clicks enter. it doesnt freeze the page
  if (!input.trim()) return;
      ## means if input is empty dont send message. .trim() means remove extra space
     const userMessage = { sender: "user", text: input };
    setMessages((prev) => [...prev, userMessage]);
    setInput("");
    setLoading(true);
    ## creates an object called userMessage. then stores all previous messages.  setinput clears input box after sending message then setloading shows AI thinking.
